# %% [markdown]
# # Scraping NUMBEO for Cost of Living Data
# https://www.numbeo.com/property-investment/
#
# Here is a starter notebook for scraping some cost of living information from NUMBEO.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from pprint import pprint
import pickle

df = pd.read_excel('../data/COST OF LIVING.xlsx')
df.head(2)
# Out:
#   REGION_ACCOUNT REGION_URL AREA_ACCOUNT              AREA_URL
# 0       I/ MEDAN      Medan         ACEH  Banda-Aceh-Indonesia
# 1       I/ MEDAN      Medan        BATAM                 Batam

# %% [markdown]
# ### Cost of Living for Each Area
# There are only 15 areas availble on the portal

# %%
df[~df.AREA_URL.isna()].AREA_ACCOUNT
# Out:
# 0            ACEH
# 1           BATAM
# 4       PEKANBARU
# 8          PADANG
# 9       PALEMBANG
# 10         BEKASI
# 11          BOGOR
# 17      TANGERANG
# 23     YOGYAKARTA
# 24       DENPASAR
# 26         MALANG
# 29     BALIKPAPAN
# 30    BANJARMASIN
# 31      PONTIANAK
# 33       MAKASSAR
# Name: AREA_ACCOUNT, dtype: object

# %%
area_dict = {}

for i, row in df[~df.AREA_URL.isna()].iterrows():
    area_url = row['AREA_URL']
    area = row['AREA_ACCOUNT']

    url_string = f'https://www.numbeo.com/property-investment/in/{area_url}'

    init_html_doc = requests.get(url_string)

    soup = BeautifulSoup(init_html_doc.content, 'lxml')
    table = soup.find(attrs={'class':'data_wide_table'})

    if table is None:
        continue
    else:
        area_dict[area] = {}
        for i, row in enumerate(table.findAll('tr')):
            if i >= 0:
                for j, data in enumerate(row.findAll('td')):
                    if j == 0:
                        key = data.text.strip().replace('\xa0','').replace('Rp','')
                    elif j == 1:
                        value = data.text.strip().replace('\xa0','').replace('Rp','')
                        area_dict[area][key] = value
                    else:
                        try:
                            left = data.find(attrs={'class':'barTextLeft'}).text.replace('\n', '')
                        except:
                            left = ''
                        try:
                            right = data.find(attrs={'class':'barTextRight'}).text.replace('\n', '')
                        except:
                            right = ''
                        area_dict[area][key] = [value, (left, right)]

# %% [markdown]
# ### Cost of Living for Each Region
#
# There are only 8 regions availble on the portal.
# If there are no area data available, we can always use the regional data instead.

# %%
df[['REGION_ACCOUNT','REGION_URL']].drop_duplicates()
# Out:
#       REGION_ACCOUNT             REGION_URL
# 0           I/ MEDAN                  Medan
# 6      II/ PALEMBANG    Palembang-Indonesia
# 10      III/ JAKARTA                Jakarta
# 18       IV/ BANDUNG                Bandung
# 21       V/ SEMARANG               Semarang
# 24      VI/ SURABAYA               Surabaya
# 29  VII/ BANJARMASIN  Banjarmasin-Indonesia
# 32    VIII/ MAKASSAR     Makassar-Indonesia

# %%
region_dict = {}

for i, row in df[['REGION_ACCOUNT','REGION_URL']].drop_duplicates().iterrows():
    region_url = row['REGION_URL']
    region = row['REGION_ACCOUNT']
    
    url_string = f'https://www.numbeo.com/property-investment/in/{region_url}'

    init_html_doc = requests.get(url_string)

    soup = BeautifulSoup(init_html_doc.content, 'lxml')
    table = soup.find(attrs={'class':'data_wide_table'})

    if table is None:
        continue
    else:
        region_dict[region] = {}
        for i, row in enumerate(table.findAll('tr')):
            if i >= 0:
                for j, data in enumerate(row.findAll('td')):
                    if j == 0:
                        key = data.text.strip().replace('\xa0','').replace('Rp','')
                    elif j == 1:
                        value = data.text.strip().replace('\xa0','').replace('Rp','')
                        region_dict[region][key] = value
                    else:
                        try:
                            left = data.find(attrs={'class':'barTextLeft'}).text.replace('\n', '')
                        except:
                            left = ''
                        try:
                            right = data.find(attrs={'class':'barTextRight'}).text.replace('\n', '')
                        except:
                            right = ''
                        region_dict[region][key] = [value, (left, right)]

# %% [markdown]
# ### Format of the ```area_dict```/```region_dict```
#
# ``` json
# AREA1:
#     {
#     FEATURE1: [MEAN VALUE, (MIN, MAX)],
#     FEATURE2: [MEAN VALUE, (MIN, MAX)]
#      },
# AREA2:
#     {
#     FEATURE1: [MEAN VALUE, (MIN, MAX)],
#     FEATURE2: [MEAN VALUE, (MIN, MAX)]
#      }
# ```

# %%
pprint(region_dict)
# Out:
# {'I/ MEDAN': {'Apartment (1 bedroom) Outside of Centre': ['1,090,000.00',
#                                                           ('700,000.00',
#                                                            '1,500,000.00')],
#               'Apartment (1 bedroom) in City Centre': ['1,800,000.00',
#                                                        ('1,000,000.00',
#                                                         '3,000,000.00')],
#               'Apartment (3 bedrooms) Outside of Centre': ['3,000,000.00',
#                                                            ('1,500,000.00',
#                                                             '5,000,000.00')],
#               'Apartment (3 bedrooms) in City Centre': ['6,875,000.00',
#                                                         ('3,000,000.00',
#                                                          '10,000,000.00')],
#               'Average Monthly Net Salary (After Tax)': ['2,998,000.00',
#                                                          ('', '')],
#               'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['9.50',
#                                                                                              ('8.00',
#                                                                                               '11.00')],
#               'Price per Square Meter to Buy Apartment Outside of Centre': ['11,500,000.00',
#                                                                             ('10,000,000.00',
#                                                                              '12,500,000.00')],
#               'Price per Square Meter to Buy Apartment in City Centre': ['25,500,000.00',
#                                                                          ('15,000,000.00',
#                                                                           '35,000,000.00')]},
#  'II/ PALEMBANG': {'Apartment (1 bedroom) Outside of Centre': ['?', ('', '')],
#                    'Apartment (1 bedroom) in City Centre': ['?', ('', '')],
#                    'Apartment (3 bedrooms) Outside of Centre': ['?', ('', '')],
#                    'Apartment (3 bedrooms) in City Centre': ['?', ('', '')],
#                    'Average Monthly Net Salary (After Tax)': ['2,700,000.00',
#                                                               ('', '')],
#                    'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['?',
#                                                                                                   ('',
#                                                                                                    '')],
#                    'Price per Square Meter to Buy Apartment Outside of Centre': ['?',
#                                                                                  ('',
#                                                                                   '')],
#                    'Price per Square Meter to Buy Apartment in City Centre': ['?',
#                                                                               ('',
#                                                                                '')]},
#  'III/ JAKARTA': {'Apartment (1 bedroom) Outside of Centre': ['3,418,491.91',
#                                                               ('2,000,000.00',
#                                                                '5,000,000.00')],
#                   'Apartment (1 bedroom) in City Centre': ['6,173,469.57',
#                                                            ('3,500,000.00',
#                                                             '10,000,000.00')],
#                   'Apartment (3 bedrooms) Outside of Centre': ['9,454,474.48',
#                                                                ('5,000,000.00',
#                                                                 '15,000,000.00')],
#                   'Apartment (3 bedrooms) in City Centre': ['21,156,463.14',
#                                                             ('10,000,000.00',
#                                                              '35,000,000.00')],
#                   'Average Monthly Net Salary (After Tax)': ['6,478,482.39',
#                                                              ('', '')],
#                   'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['9.90',
#                                                                                                  ('7.00',
#                                                                                                   '12.00')],
#                   'Price per Square Meter to Buy Apartment Outside of Centre': ['16,613,636.36',
#                                                                                 ('10,000,000.00',
#                                                                                  '20,000,000.00')],
#                   'Price per Square Meter to Buy Apartment in City Centre': ['33,421,586.00',
#                                                                              ('20,000,000.00',
#                                                                               '50,000,000.00')]},
#  'IV/ BANDUNG': {'Apartment (1 bedroom) Outside of Centre': ['2,137,371.46',
#                                                              ('1,500,000.00',
#                                                               '3,500,000.00')],
#                  'Apartment (1 bedroom) in City Centre': ['3,977,777.78',
#                                                           ('2,500,000.00',
#                                                            '6,500,000.00')],
#                  'Apartment (3 bedrooms) Outside of Centre': ['5,484,085.78',
#                                                               ('4,000,000.00',
#                                                                '8,000,000.00')],
#                  'Apartment (3 bedrooms) in City Centre': ['8,259,650.11',
#                                                            ('6,000,000.00',
#                                                             '10,000,000.00')],
#                  'Average Monthly Net Salary (After Tax)': ['4,263,636.36',
#                                                             ('', '')],
#                  'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['9.80',
#                                                                                                 ('9.00',
#                                                                                                  '10.00')],
#                  'Price per Square Meter to Buy Apartment Outside of Centre': ['7,779,547.77',
#                                                                                ('5,000,000.00',
#                                                                                 '10,261,286.62')],
#                  'Price per Square Meter to Buy Apartment in City Centre': ['16,894,300.21',
#                                                                             ('14,365,801.27',
#                                                                              '25,000,000.00')]},
#  'V/ SEMARANG': {'Apartment (1 bedroom) Outside of Centre': ['2,666,666.67',
#                                                              ('2,500,000.00',
#                                                               '3,000,000.00')],
#                  'Apartment (1 bedroom) in City Centre': ['4,000,000.00',
#                                                           ('3,500,000.00',
#                                                            '4,500,000.00')],
#                  'Apartment (3 bedrooms) Outside of Centre': ['5,516,666.67',
#                                                               ('3,050,000.00',
#                                                                '8,500,000.00')],
#                  'Apartment (3 bedrooms) in City Centre': ['8,166,666.67',
#                                                            ('7,000,000.00',
#                                                             '10,500,000.00')],
#                  'Average Monthly Net Salary (After Tax)': ['3,200,000.00',
#                                                             ('', '')],
#                  'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['9.67',
#                                                                                                 ('5.00',
#                                                                                                  '12.00')],
#                  'Price per Square Meter to Buy Apartment Outside of Centre': ['9,166,666.67',
#                                                                                ('5,000,000.00',
#                                                                                 '15,000,000.00')],
#                  'Price per Square Meter to Buy Apartment in City Centre': ['17,166,666.67',
#                                                                             ('9,000,000.00',
#                                                                              '25,000,000.00')]},
#  'VI/ SURABAYA': {'Apartment (1 bedroom) Outside of Centre': ['2,370,333.33',
#                                                               ('1,500,000.00',
#                                                                '3,000,000.00')],
#                   'Apartment (1 bedroom) in City Centre': ['3,762,500.00',
#                                                            ('2,500,000.00',
#                                                             '5,000,000.00')],
#                   'Apartment (3 bedrooms) Outside of Centre': ['6,800,000.00',
#                                                                ('3,500,000.00',
#                                                                 '12,000,000.00')],
#                   'Apartment (3 bedrooms) in City Centre': ['10,500,000.00',
#                                                             ('8,000,000.00',
#                                                              '15,000,000.00')],
#                   'Average Monthly Net Salary (After Tax)': ['4,266,666.67',
#                                                              ('', '')],
#                   'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['9.80',
#                                                                                                  ('9.00',
#                                                                                                   '10.00')],
#                   'Price per Square Meter to Buy Apartment Outside of Centre': ['15,989,018.75',
#                                                                                 ('5,000,000.00',
#                                                                                  '20,000,000.00')],
#                   'Price per Square Meter to Buy Apartment in City Centre': ['21,322,352.09',
#                                                                              ('15,000,000.00',
#                                                                               '40,000,000.00')]},
#  'VII/ BANJARMASIN': {'Apartment (1 bedroom) Outside of Centre': ['1,000,000.00',
#                                                                   ('1,000,000.00',
#                                                                    '1,000,000.00')],
#                       'Apartment (1 bedroom) in City Centre': ['2,250,000.00',
#                                                                ('2,000,000.00',
#                                                                 '2,500,000.00')],
#                       'Apartment (3 bedrooms) Outside of Centre': ['2,000,000.00',
#                                                                    ('2,000,000.00',
#                                                                     '2,000,000.00')],
#                       'Apartment (3 bedrooms) in City Centre': ['4,000,000.00',
#                                                                 ('3,000,000.00',
#                                                                  '5,000,000.00')],
#                       'Average Monthly Net Salary (After Tax)': ['3,129,304.60',
#                                                                  ('', '')],
#                       'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['10.00',
#                                                                                                      ('10.00',
#                                                                                                       '10.00')],
#                       'Price per Square Meter to Buy Apartment Outside of Centre': ['3,000,000.00',
#                                                                                     ('',
#                                                                                      '')],
#                       'Price per Square Meter to Buy Apartment in City Centre': ['5,000,000.00',
#                                                                                  ('',
#                                                                                   '')]},
#  'VIII/ MAKASSAR': {'Apartment (1 bedroom) Outside of Centre': ['650,000.00',
#                                                                 ('550,000.00',
#                                                                  '750,000.00')],
#                     'Apartment (1 bedroom) in City Centre': ['1,750,000.00',
#                                                              ('1,000,000.00',
#                                                               '5,000,000.00')],
#                     'Apartment (3 bedrooms) Outside of Centre': ['1,500,000.00',
#                                                                  ('', '')],
#                     'Apartment (3 bedrooms) in City Centre': ['6,250,000.00',
#                                                               ('2,500,000.00',
#                                                                '10,000,000.00')],
#                     'Average Monthly Net Salary (After Tax)': ['4,333,333.33',
#                                                                ('', '')],
#                     'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['11.00',
#                                                                                                    ('8.00',
#                                                                                                     '14.00')],
#                     'Price per Square Meter to Buy Apartment Outside of Centre': ['3,000,000.00',
#                                                                                   ('',
#                                                                                    '')],
#                     'Price per Square Meter to Buy Apartment in City Centre': ['15,000,000.00',
#                                                                                ('10,000,000.00',
#                                                                                 '20,000,000.00')]}}

# %%
pprint(area_dict)
# Out:
# {'ACEH': {'Apartment (1 bedroom) Outside of Centre': ['?', ('', '')],
#           'Apartment (1 bedroom) in City Centre': ['?', ('', '')],
#           'Apartment (3 bedrooms) Outside of Centre': ['?', ('', '')],
#           'Apartment (3 bedrooms) in City Centre': ['?', ('', '')],
#           'Average Monthly Net Salary (After Tax)': ['2,950,000.00', ('', '')],
#           'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['?',
#                                                                                          ('',
#                                                                                           '')],
#           'Price per Square Meter to Buy Apartment Outside of Centre': ['?',
#                                                                         ('',
#                                                                          '')],
#           'Price per Square Meter to Buy Apartment in City Centre': ['?',
#                                                                      ('', '')]},
#  'BALIKPAPAN': {'Apartment (1 bedroom) Outside of Centre': ['1,250,000.00',
#                                                             ('1,000,000.00',
#                                                              '1,500,000.00')],
#                 'Apartment (1 bedroom) in City Centre': ['2,500,000.00',
#                                                          ('2,500,000.00',
#                                                           '2,500,000.00')],
#                 'Apartment (3 bedrooms) Outside of Centre': ['3,000,000.00',
#                                                              ('3,000,000.00',
#                                                               '3,000,000.00')],
#                 'Apartment (3 bedrooms) in City Centre': ['4,250,000.00',
#                                                           ('3,500,000.00',
#                                                            '5,000,000.00')],
#                 'Average Monthly Net Salary (After Tax)': ['6,833,333.33',
#                                                            ('', '')],
#                 'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['?',
#                                                                                                ('',
#                                                                                                 '')],
#                 'Price per Square Meter to Buy Apartment Outside of Centre': ['3,000,000.00',
#                                                                               ('',
#                                                                                '')],
#                 'Price per Square Meter to Buy Apartment in City Centre': ['?',
#                                                                            ('',
#                                                                             '')]},
#  'BANJARMASIN': {'Apartment (1 bedroom) Outside of Centre': ['1,000,000.00',
#                                                              ('1,000,000.00',
#                                                               '1,000,000.00')],
#                  'Apartment (1 bedroom) in City Centre': ['2,250,000.00',
#                                                           ('2,000,000.00',
#                                                            '2,500,000.00')],
#                  'Apartment (3 bedrooms) Outside of Centre': ['2,000,000.00',
#                                                               ('2,000,000.00',
#                                                                '2,000,000.00')],
#                  'Apartment (3 bedrooms) in City Centre': ['4,000,000.00',
#                                                            ('3,000,000.00',
#                                                             '5,000,000.00')],
#                  'Average Monthly Net Salary (After Tax)': ['3,129,304.60',
#                                                             ('', '')],
#                  'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['10.00',
#                                                                                                 ('10.00',
#                                                                                                  '10.00')],
#                  'Price per Square Meter to Buy Apartment Outside of Centre': ['3,000,000.00',
#                                                                                ('',
#                                                                                 '')],
#                  'Price per Square Meter to Buy Apartment in City Centre': ['5,000,000.00',
#                                                                             ('',
#                                                                              '')]},
#  'BATAM': {'Apartment (1 bedroom) Outside of Centre': ['2,050,000.00',
#                                                        ('600,000.00',
#                                                         '3,500,000.00')],
#            'Apartment (1 bedroom) in City Centre': ['5,000,000.00', ('', '')],
#            'Apartment (3 bedrooms) Outside of Centre': ['7,000,000.00',
#                                                         ('', '')],
#            'Apartment (3 bedrooms) in City Centre': ['10,000,000.00', ('', '')],
#            'Average Monthly Net Salary (After Tax)': ['3,548,951.33', ('', '')],
#            'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['9.00',
#                                                                                           ('7.00',
#                                                                                            '11.00')],
#            'Price per Square Meter to Buy Apartment Outside of Centre': ['13,000,000.00',
#                                                                          ('',
#                                                                           '')],
#            'Price per Square Meter to Buy Apartment in City Centre': ['18,500,000.00',
#                                                                       ('17,000,000.00',
#                                                                        '20,000,000.00')]},
#  'BEKASI': {'Apartment (1 bedroom) Outside of Centre': ['3,000,000.00',
#                                                         ('2,000,000.00',
#                                                          '5,000,000.00')],
#             'Apartment (1 bedroom) in City Centre': ['4,333,333.33',
#                                                      ('2,500,000.00',
#                                                       '6,500,000.00')],
#             'Apartment (3 bedrooms) Outside of Centre': ['5,666,666.67',
#                                                          ('4,500,000.00',
#                                                           '7,500,000.00')],
#             'Apartment (3 bedrooms) in City Centre': ['6,000,000.00',
#                                                       ('3,000,000.00',
#                                                        '10,000,000.00')],
#             'Average Monthly Net Salary (After Tax)': ['6,898,000.00',
#                                                        ('', '')],
#             'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['11.00',
#                                                                                            ('11.00',
#                                                                                             '11.00')],
#             'Price per Square Meter to Buy Apartment Outside of Centre': ['13,500,000.00',
#                                                                           ('12,500,000.00',
#                                                                            '15,000,000.00')],
#             'Price per Square Meter to Buy Apartment in City Centre': ['16,250,000.00',
#                                                                        ('15,000,000.00',
#                                                                         '20,833,000.00')]},
#  'BOGOR': {'Apartment (1 bedroom) Outside of Centre': ['2,250,000.00',
#                                                        ('2,000,000.00',
#                                                         '2,500,000.00')],
#            'Apartment (1 bedroom) in City Centre': ['3,250,000.00',
#                                                     ('2,500,000.00',
#                                                      '4,000,000.00')],
#            'Apartment (3 bedrooms) Outside of Centre': ['5,000,000.00',
#                                                         ('', '')],
#            'Apartment (3 bedrooms) in City Centre': ['5,000,000.00', ('', '')],
#            'Average Monthly Net Salary (After Tax)': ['3,016,666.67', ('', '')],
#            'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['10.50',
#                                                                                           ('7.00',
#                                                                                            '14.00')],
#            'Price per Square Meter to Buy Apartment Outside of Centre': ['14,000,000.00',
#                                                                          ('11,000,000.00',
#                                                                           '17,000,000.00')],
#            'Price per Square Meter to Buy Apartment in City Centre': ['15,000,000.00',
#                                                                       ('13,000,000.00',
#                                                                        '17,000,000.00')]},
#  'DENPASAR': {'Apartment (1 bedroom) Outside of Centre': ['2,100,000.00',
#                                                           ('1,500,000.00',
#                                                            '4,000,000.00')],
#               'Apartment (1 bedroom) in City Centre': ['3,500,000.00',
#                                                        ('2,500,000.00',
#                                                         '8,000,000.00')],
#               'Apartment (3 bedrooms) Outside of Centre': ['4,400,000.00',
#                                                            ('4,000,000.00',
#                                                             '5,000,000.00')],
#               'Apartment (3 bedrooms) in City Centre': ['6,100,000.00',
#                                                         ('5,000,000.00',
#                                                          '7,000,000.00')],
#               'Average Monthly Net Salary (After Tax)': ['2,662,500.00',
#                                                          ('', '')],
#               'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['12.00',
#                                                                                              ('11.00',
#                                                                                               '15.00')],
#               'Price per Square Meter to Buy Apartment Outside of Centre': ['7,000,000.00',
#                                                                             ('',
#                                                                              '')],
#               'Price per Square Meter to Buy Apartment in City Centre': ['10,000,000.00',
#                                                                          ('',
#                                                                           '')]},
#  'MAKASSAR': {'Apartment (1 bedroom) Outside of Centre': ['650,000.00',
#                                                           ('550,000.00',
#                                                            '750,000.00')],
#               'Apartment (1 bedroom) in City Centre': ['1,750,000.00',
#                                                        ('1,000,000.00',
#                                                         '5,000,000.00')],
#               'Apartment (3 bedrooms) Outside of Centre': ['1,500,000.00',
#                                                            ('', '')],
#               'Apartment (3 bedrooms) in City Centre': ['6,250,000.00',
#                                                         ('2,500,000.00',
#                                                          '10,000,000.00')],
#               'Average Monthly Net Salary (After Tax)': ['4,333,333.33',
#                                                          ('', '')],
#               'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['11.00',
#                                                                                              ('8.00',
#                                                                                               '14.00')],
#               'Price per Square Meter to Buy Apartment Outside of Centre': ['3,000,000.00',
#                                                                             ('',
#                                                                              '')],
#               'Price per Square Meter to Buy Apartment in City Centre': ['15,000,000.00',
#                                                                          ('10,000,000.00',
#                                                                           '20,000,000.00')]},
#  'MALANG': {'Apartment (1 bedroom) Outside of Centre': ['1,100,000.00',
#                                                         ('500,000.00',
#                                                          '2,500,000.00')],
#             'Apartment (1 bedroom) in City Centre': ['2,333,333.33',
#                                                      ('1,000,000.00',
#                                                       '3,000,000.00')],
#             'Apartment (3 bedrooms) Outside of Centre': ['4,500,000.00',
#                                                          ('1,500,000.00',
#                                                           '9,000,000.00')],
#             'Apartment (3 bedrooms) in City Centre': ['7,500,000.00',
#                                                       ('3,000,000.00',
#                                                        '12,000,000.00')],
#             'Average Monthly Net Salary (After Tax)': ['3,833,333.33',
#                                                        ('', '')],
#             'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['8.33',
#                                                                                            ('5.00',
#                                                                                             '12.00')],
#             'Price per Square Meter to Buy Apartment Outside of Centre': ['5,250,000.00',
#                                                                           ('3,000,000.00',
#                                                                            '7,500,000.00')],
#             'Price per Square Meter to Buy Apartment in City Centre': ['10,000,000.00',
#                                                                        ('5,000,000.00',
#                                                                         '15,000,000.00')]},
#  'PADANG': {'Apartment (1 bedroom) Outside of Centre': ['750,000.00',
#                                                         ('500,000.00',
#                                                          '1,000,000.00')],
#             'Apartment (1 bedroom) in City Centre': ['2,250,000.00',
#                                                      ('1,000,000.00',
#                                                       '3,500,000.00')],
#             'Apartment (3 bedrooms) Outside of Centre': ['8,000,000.00',
#                                                          ('', '')],
#             'Apartment (3 bedrooms) in City Centre': ['10,000,000.00',
#                                                       ('', '')],
#             'Average Monthly Net Salary (After Tax)': ['2,500,000.00',
#                                                        ('', '')],
#             'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['?',
#                                                                                            ('',
#                                                                                             '')],
#             'Price per Square Meter to Buy Apartment Outside of Centre': ['?',
#                                                                           ('',
#                                                                            '')],
#             'Price per Square Meter to Buy Apartment in City Centre': ['?',
#                                                                        ('',
#                                                                         '')]},
#  'PALEMBANG': {'Apartment (1 bedroom) Outside of Centre': ['?', ('', '')],
#                'Apartment (1 bedroom) in City Centre': ['?', ('', '')],
#                'Apartment (3 bedrooms) Outside of Centre': ['?', ('', '')],
#                'Apartment (3 bedrooms) in City Centre': ['?', ('', '')],
#                'Average Monthly Net Salary (After Tax)': ['2,700,000.00',
#                                                           ('', '')],
#                'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['?',
#                                                                                               ('',
#                                                                                                '')],
#                'Price per Square Meter to Buy Apartment Outside of Centre': ['?',
#                                                                              ('',
#                                                                               '')],
#                'Price per Square Meter to Buy Apartment in City Centre': ['?',
#                                                                           ('',
#                                                                            '')]},
#  'PEKANBARU': {'Apartment (1 bedroom) Outside of Centre': ['?', ('', '')],
#                'Apartment (1 bedroom) in City Centre': ['1,500,000.00',
#                                                         ('', '')],
#                'Apartment (3 bedrooms) Outside of Centre': ['?', ('', '')],
#                'Apartment (3 bedrooms) in City Centre': ['3,000,000.00',
#                                                          ('', '')],
#                'Average Monthly Net Salary (After Tax)': ['6,166,666.67',
#                                                           ('', '')],
#                'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['18.00',
#                                                                                               ('',
#                                                                                                '')],
#                'Price per Square Meter to Buy Apartment Outside of Centre': ['?',
#                                                                              ('',
#                                                                               '')],
#                'Price per Square Meter to Buy Apartment in City Centre': ['4,000,000.00',
#                                                                           ('',
#                                                                            '')]},
#  'PONTIANAK': {'Apartment (1 bedroom) Outside of Centre': ['750,000.00',
#                                                            ('', '')],
#                'Apartment (1 bedroom) in City Centre': ['1,000,000.00',
#                                                         ('', '')],
#                'Apartment (3 bedrooms) Outside of Centre': ['?', ('', '')],
#                'Apartment (3 bedrooms) in City Centre': ['?', ('', '')],
#                'Average Monthly Net Salary (After Tax)': ['2,400,000.00',
#                                                           ('', '')],
#                'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['?',
#                                                                                               ('',
#                                                                                                '')],
#                'Price per Square Meter to Buy Apartment Outside of Centre': ['?',
#                                                                              ('',
#                                                                               '')],
#                'Price per Square Meter to Buy Apartment in City Centre': ['?',
#                                                                           ('',
#                                                                            '')]},
#  'TANGERANG': {'Apartment (1 bedroom) Outside of Centre': ['2,250,000.00',
#                                                            ('1,500,000.00',
#                                                             '3,000,000.00')],
#                'Apartment (1 bedroom) in City Centre': ['4,500,000.00',
#                                                         ('3,000,000.00',
#                                                          '6,000,000.00')],
#                'Apartment (3 bedrooms) Outside of Centre': ['6,833,333.33',
#                                                             ('4,000,000.00',
#                                                              '8,500,000.00')],
#                'Apartment (3 bedrooms) in City Centre': ['9,666,666.67',
#                                                          ('4,000,000.00',
#                                                           '15,000,000.00')],
#                'Average Monthly Net Salary (After Tax)': ['4,608,333.33',
#                                                           ('', '')],
#                'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['10.62',
#                                                                                               ('9.00',
#                                                                                                '14.00')],
#                'Price per Square Meter to Buy Apartment Outside of Centre': ['13,500,000.00',
#                                                                              ('10,000,000.00',
#                                                                               '24,000,000.00')],
#                'Price per Square Meter to Buy Apartment in City Centre': ['27,666,666.67',
#                                                                           ('20,000,000.00',
#                                                                            '43,000,000.00')]},
#  'YOGYAKARTA': {'Apartment (1 bedroom) Outside of Centre': ['2,060,000.00',
#                                                             ('1,000,000.00',
#                                                              '4,000,000.00')],
#                 'Apartment (1 bedroom) in City Centre': ['2,414,285.71',
#                                                          ('1,000,000.00',
#                                                           '4,500,000.00')],
#                 'Apartment (3 bedrooms) Outside of Centre': ['5,875,000.00',
#                                                              ('3,500,000.00',
#                                                               '10,000,000.00')],
#                 'Apartment (3 bedrooms) in City Centre': ['7,833,333.33',
#                                                           ('2,500,000.00',
#                                                            '30,000,000.00')],
#                 'Average Monthly Net Salary (After Tax)': ['2,043,750.00',
#                                                            ('', '')],
#                 'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate': ['13.00',
#                                                                                                ('12.00',
#                                                                                                 '15.00')],
#                 'Price per Square Meter to Buy Apartment Outside of Centre': ['5,500,000.00',
#                                                                               ('2,500,000.00',
#                                                                                '15,000,000.00')],
#                 'Price per Square Meter to Buy Apartment in City Centre': ['14,028,571.40',
#                                                                            ('5,000,000.00',
#                                                                             '27,142,857.00')]}}

# %% [markdown]
# ### Saving to pickle files

# %%
with open('../data/region_dict.pickle', 'wb') as handle:
    pickle.dump(region_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('../data/area_dict.pickle', 'wb') as handle:
    pickle.dump(area_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
