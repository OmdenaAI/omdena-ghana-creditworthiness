# %% [markdown]
# ### This notebook seeks to prepare and present a unique ready to operate data set for operation in the task-02 and above tasks by:
# * Merging similar datasets, columns

# %%
# importing relevant libraries/modules 

import pandas as pd 
import numpy as np

# %%
# loading all datasets in the task-01-data-collection folder

ghana_mobile_money = pd.read_csv("Ghana_Mobile_Money_Data.csv")
ghana_income = pd.read_csv("cfafrica-ghana-income.csv")
finscope = pd.read_csv("finscope_VariableDefinitions.csv")
dev_indicators = pd.read_csv("API_Download.csv") 

# checking the number of rows and columns 
print(finscope.shape)
print(ghana_mobile_money.shape)
print(ghana_income.shape)
print(dev_indicators.shape)
# Out:
# (12, 2)
# (7, 4)
# (11, 5)
# (2886, 65)

# %%
# detailed information about each dataset
finscope
# Out:
#       Variable Definitions                                         Unnamed: 1
# 0                  country                         Country interviewee is in.
# 1                     year                           Year survey was done in.
# 2                 uniqueid             Unique identifier for each interviewee
# 3            location_type                     Type of location: Rural, Urban
# 4         cellphone_access  If interviewee has access to a cellphone: Yes, No
# 5           household_size               Number of people living in one house
# 6        age_of_respondent                         The age of the interviewee
# 7     gender_of_respondent                Gender of interviewee: Male, Female
# 8   relationship_with_head  The interviewee’s relationship with the head o...
# 9           marital_status  The martial status of the interviewee: Married...
# 10         education_level  Highest level of education: No formal educatio...
# ...

# %%
ghana_mobile_money
# Out:
#        DATE  Total Population  Registered Mobile Bank Account  \
# 0  1/1/2012          25996449                         3778374
# 1  1/1/2013          26607642                         4393721
# 2  1/1/2014          27224472                         7167542
# 3  1/1/2015          27849205                        13120367
# 4  1/1/2016          28481946                        19735098
# 5  1/1/2017          29121471                        23947437
# 6  1/1/2018          29767108                        32554346
#
#    Commercial Bank Accounts per 1000 Adults
# 0                                   455.461
# 1                                   456.351
# 2                                   501.158
# 3                                   595.370
# 4                                   554.728
# 5                                   627.307
# 6                                       NaN

# %%
ghana_income
# Out:
#            Region Mean annual household income (GH?)  \
# 0         Western                             30,862
# 1         Central                             32,564
# 2   Greater Accra                             64,701
# 3           Volta                             31,612
# 4         Eastern                             21,592
# 5         Ashanti                             72,491
# 6     Brong Ahafo                             30,710
# 7        Northern                             22,919
# 8      Upper East                             16,130
# 9      Upper West                             12,958
# 10          Ghana                             44,042
#
#    Mean annual per capita income Avg cost of living(per person)  \
# 0                          9,058                       3,489.75
# 1                         12,189                       3,489.75
# 2                         21,592                       3,489.75
# 3                          7,394                       3,489.75
# ...

# %%
dev_indicators.head()
# Out:
#   Country Name Country Code  \
# 0        Ghana          GHA
# 1        Ghana          GHA
# 2        Ghana          GHA
# 3        Ghana          GHA
# 4        Ghana          GHA
#
#                                       Indicator Name        Indicator Code  \
# 0  Internally displaced persons, total displaced ...           VC.IDP.TOCV
# 1  Merchandise exports to low- and middle-income ...     TX.VAL.MRCH.R4.ZS
# 2                   Export volume index (2000 = 100)     TX.QTY.MRCH.XD.WD
# 3  Merchandise imports from low- and middle-incom...     TM.VAL.MRCH.R1.ZS
# 4  Tariff rate, most favored nation, simple mean,...  TM.TAX.TCOM.SM.FN.ZS
#
#        1960      1961      1962      1963      1964      1965  ...  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN  ...
# 1  0.215252  0.031027  0.278983  0.196980  0.529265  0.472144  ...
# 2       NaN       NaN       NaN       NaN       NaN       NaN  ...
# 3  0.828500  0.626881  1.200480  0.631521  0.881834  3.303571  ...
# ...
